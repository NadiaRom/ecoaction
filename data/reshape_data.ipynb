# %%
import pandas as pd, json, matplotlib.pyplot as plt
from pdb import set_trace
# %matplotlib inline

# %%
ls *.csv
# Out:
# costs.csv           data_by_sphere_wide.csv  scenario.csv
# data_by_source.csv  data_from_report.csv
# data_by_sphere.csv  data_report_longest.csv

# %%
sc = pd.read_csv('scenario.csv')

# %%
df = pd.read_csv('data_by_sphere.csv')

# %%
sum_by_sphere = df.loc[df.year == 2012].groupby('sphere', as_index=False).k_t_ne.sum()
sum_by_sphere.columns = ['sphere', 'total_ktne']

# %%
df
# Out:
#                      source  is_vde                 sphere  year   k_t_ne
# 0                       Газ       0                 Всього  2012  21698.0
# 1           Теплова енергія       0                 Всього  2012  11853.0
# 2    Нафта та нафтопродукти       0                 Всього  2012  11347.0
# 3            Електроенергія       0                 Всього  2012  11130.0
# 4                   Вугілля       0                 Всього  2012   9212.0
# 5      Біопаливо та відходи       1                 Всього  2012   1029.0
# 6      Електроенергія з ВДЕ       1                 Всього  2012    710.0
# 7     Теплова енергія з ВДЕ       1                 Всього  2012     12.3
# 8           Сонячна енергія       1                 Всього  2012      0.0
# 9                       Газ       0                 Всього  2035   7615.0
# 10           Електроенергія       0                 Всього  2035   6457.0
# 11          Теплова енергія       0                 Всього  2035   6435.0
# 12   Нафта та нафтопродукти       0                 Всього  2035   5873.0
# 13                  Вугілля       0                 Всього  2035   5419.0
# 14     Електроенергія з ВДЕ       1                 Всього  2035  10964.0
# 15     Біопаливо та відходи       1                 Всього  2035   5695.0
# 16    Теплова енергія з ВДЕ       1                 Всього  2035   3904.0
# 17          Сонячна енергія       1                 Всього  2035    657.0
# 18           Електроенергія       0                 Всього  2050   1920.0
# 19          Теплова енергія       0                 Всього  2050   1604.0
# 20                  Вугілля       0                 Всього  2050    621.0
# 21                      Газ       0                 Всього  2050    460.1
# 22   Нафта та нафтопродукти       0                 Всього  2050      3.0
# 23     Електроенергія з ВДЕ       1                 Всього  2050  25292.0
# 24    Теплова енергія з ВДЕ       1                 Всього  2050   7446.0
# 25     Біопаливо та відходи       1                 Всього  2050   7334.0
# 26          Сонячна енергія       1                 Всього  2050   4316.0
# 27                  Вугілля       0          Промисловість  2012   8310.0
# 28                      Газ       0          Промисловість  2012   5272.0
# 29           Електроенергія       0          Промисловість  2012   5102.0
# ..                      ...     ...                    ...   ...      ...
# 132         Сонячна енергія       1           Сфера послуг  2050   1012.0
# 133   Теплова енергія з ВДЕ       1           Сфера послуг  2050    850.0
# 134    Біопаливо та відходи       1           Сфера послуг  2050     80.0
# 135  Нафта та нафтопродукти       0  Сільське господарство  2012   1364.0
# 136          Електроенергія       0  Сільське господарство  2012    312.0
# 137         Теплова енергія       0  Сільське господарство  2012    312.0
# 138                     Газ       0  Сільське господарство  2012    153.0
# 139                 Вугілля       0  Сільське господарство  2012     14.0
# 140    Біопаливо та відходи       1  Сільське господарство  2012     20.0
# 141    Електроенергія з ВДЕ       1  Сільське господарство  2012     20.0
# 142   Теплова енергія з ВДЕ       1  Сільське господарство  2012      0.3
# 143         Сонячна енергія       1  Сільське господарство  2012      0.0
# 144  Нафта та нафтопродукти       0  Сільське господарство  2035    771.0
# 145         Теплова енергія       0  Сільське господарство  2035    247.0
# 146          Електроенергія       0  Сільське господарство  2035    144.0
# 147                     Газ       0  Сільське господарство  2035    104.0
# 148                 Вугілля       0  Сільське господарство  2035      2.0
# 149    Біопаливо та відходи       1  Сільське господарство  2035   1119.0
# 150    Електроенергія з ВДЕ       1  Сільське господарство  2035    245.0
# 151   Теплова енергія з ВДЕ       1  Сільське господарство  2035    150.0
# 152         Сонячна енергія       1  Сільське господарство  2035      0.0
# 153         Теплова енергія       0  Сільське господарство  2050     84.0
# 154          Електроенергія       0  Сільське господарство  2050     33.0
# 155                     Газ       0  Сільське господарство  2050      0.0
# 156                 Вугілля       0  Сільське господарство  2050      0.0
# 157  Нафта та нафтопродукти       0  Сільське господарство  2050      0.0
# 158    Біопаливо та відходи       1  Сільське господарство  2050   2232.0
# 159    Електроенергія з ВДЕ       1  Сільське господарство  2050    439.0
# 160   Теплова енергія з ВДЕ       1  Сільське господарство  2050    388.0
# 161         Сонячна енергія       1  Сільське господарство  2050      0.0
#
# [162 rows x 5 columns]

# %%
df = df.merge(sum_by_sphere, on='sphere', how='left')
df.sphere = df.sphere.apply(str.capitalize)
df.sphere = df.sphere.str.replace('Total', 'Всього')

# %%
df.sort_values(['total_ktne', 'sphere', 'year', 'is_vde', 'k_t_ne'], ascending=[False, True, True, True, False]
              ).drop('total_ktne', axis=1
              ).to_csv('data_by_sphere.csv', index=False)

# %%
measures = {
    'ДОМОГОСПОДАРСТВА': [
        'Термомодернізація житлових будинків',
        'Модернізація систем енергозабезпечення об’єктів ЖКГ',
        'Автоматизовані індивідуальні теплові пункти (ІТП)',
        'Впровадження когенераційних систем для багатоповерхових будинків',
        'Техніка А++, А+++',
        '40-50% населення використовує сонячні панелі на дахах будинків',
        'Опалення та гаряча вода за рахунок біопалива та відходів, централізованого ВДЕ-тепла та використання сонячних колекторів',
    ],
    'ТРАНСПОРТ': [
        'Легкові авто: 90% електромобілі, 10% на біопаливі',
        'Електроавтобуси та електропотяги',
        'Авіаційний, водний, вантажний транспорт на біопаливі',
    ],
    'ПРОМИСЛОВІСТЬ': [
        '88% - енергія з відновлюваних джерел та альтернативних видів палива',
        'Електрифікація промисловості',
        'Заміна енергоємного обладнання на нове та ефективне',
        'Більші інвестиції з боку промислових виробників, зокрема електроенергетичної галузі',
    ],
    'СІЛЬСЬКЕ ГОСПОДАРСТВО': [
        'Використання ВДЕ для виробництва електроенергії та тепла',
        'СГ Транспорт на біопаливі',
        'Вирощування енергетичних культур',
        'Нові технології використання сільськогосподарських машин та механізмів',
    ],
    'СФЕРА ПОСЛУГ': [
        'ВДЕ 88%',
        'Заходи з енергоефективності та енергозаощадження',
        'Термоізоляція приміщень',
        'Використання високоефективних технічних приладів (А++, А+++)',
    ],
    'Всього': [
        'Економічні наслідки:',
        'Скорочення потреб в енергоресурсах на 42%',
        'Економія до 75% енергоресурсів для опалення завдяки повній реконструкції будинків',
        'Економія 30% коштів завдяки енергоефективності та енергозбереженню',
        'Енергоємність ВВП України знизиться у 3  рази',
        'Не потрібно імпортувати газ, вугілля, ядерне паливо',
        'Соціальні наслідки:',
        'Нова енергетична інфраструктура',
        'Нові робочі місця в галузі ВДЕ та енергоефективності',
        'Нові можливості для розвитку на місцях: локальне виробництво енергії, використання місцевих ресурсів',
        'Зменшення кількості працівників у видобувній галузі',
        'Скорочення викидів парникових газів 90 %  від рівня 1990 р.',
        'Зниження негативного впливу від енергетики на здоров’я людей',
    ]
}

# %%
def reshape_df(d):
    new = d.pivot('year', 'source', 'k_t_ne').reset_index()
    new['sphere'] = d.sphere.iloc[0]
    return new.reindex(['year', 'sphere', 'Біопаливо та відходи', 'Вугілля', 'Газ', 'Електроенергія',
       'Електроенергія з ВДЕ', 'Нафта та нафтопродукти', 'Сонячна енергія',
       'Теплова енергія', 'Теплова енергія з ВДЕ'], axis=1)

# %%
df.groupby(['year', 'sphere'], as_index=False).apply(reshape_df).reset_index(drop=True).fillna(0)
# Out:
# source  year                 sphere  Біопаливо та відходи  Вугілля      Газ  \
# 0       2012                 Всього                1029.0   9212.0  21698.0
# 1       2012       Домогосподарства                 936.0    715.0  13760.0
# 2       2012          Промисловість                  46.0   8310.0   5272.0
# 3       2012           Сфера послуг                  27.0    161.0    463.0
# 4       2012  Сільське господарство                  20.0     14.0    153.0
# 5       2012              Транспорт                   0.0     12.0   2050.0
# 6       2035                 Всього                5695.0   5419.0   7615.0
# 7       2035       Домогосподарства                 137.0    395.0   5450.0
# 8       2035          Промисловість                 478.0   4910.0   1552.0
# 9       2035           Сфера послуг                 440.0    100.0    295.0
# 10      2035  Сільське господарство                1119.0      2.0    104.0
# 11      2035              Транспорт                3521.0     12.0    214.0
# 12      2050                 Всього                7334.0    621.0    460.1
# 13      2050       Домогосподарства                   0.0      0.0      0.0
# 14      2050          Промисловість                1235.0    547.0    276.0
# 15      2050           Сфера послуг                  80.0     74.0    184.0
# 16      2050  Сільське господарство                2232.0      0.0      0.0
# 17      2050              Транспорт                3787.0      0.0      0.1
#
# source  Електроенергія  Електроенергія з ВДЕ  Нафта та нафтопродукти  \
# 0              11130.0                 710.0                 11347.0
# 1               3105.0                 198.0                    71.0
# 2               5102.0                   0.0                  1246.0
# 3               1861.0                 119.0                    78.0
# 4                312.0                  20.0                  1364.0
# 5                750.0                  48.0                  8588.0
# 6               6457.0               10964.0                  5873.0
# 7               1325.0                2251.0                     0.0
# 8               3374.0                   0.0                   676.0
# 9                967.0                1642.0                     0.0
# 10               144.0                 245.0                   771.0
# 11               647.0                1098.0                  4426.0
# 12              1920.0               25292.0                     3.0
# 13               403.0                5309.0                     0.0
# 14               983.0                   0.0                     0.0
# 15               247.0                3252.0                     0.0
# 16                33.0                 439.0                     0.0
# 17               254.0                3346.0                     3.0
#
# source  Сонячна енергія  Теплова енергія  Теплова енергія з ВДЕ
# 0                   0.0          11853.0                   12.3
# 1                   0.0           4677.0                    5.0
# 2                   0.0           4538.0                    5.0
# 3                   0.0           2326.0                    2.0
# 4                   0.0            312.0                    0.3
# 5                   0.0              0.0                    0.0
# 6                 657.0           6435.0                 3904.0
# 7                 642.0           2867.0                 1739.0
# 8                   0.0           2090.0                 1268.0
# 9                  14.0           1231.0                  747.0
# 10                  0.0            247.0                  150.0
# 11                  0.0              0.0                    0.0
# 12               4316.0           1604.0                 7446.0
# 13               3304.0            834.0                 3873.0
# 14                  0.0            503.0                 2335.0
# 15               1012.0            183.0                  850.0
# 16                  0.0             84.0                  388.0
# 17               3346.0              0.0                    0.0

# %%
def reshape_df(d):
    new = d.pivot('year', 'sphere', 'k_t_ne').reset_index()
    new['source'] = d.source.iloc[0]
    new['is_vde'] = d.is_vde.iloc[0]
    return new.reindex(['year', 'source', 'is_vde', 'Всього', 'Промисловість', 'Домогосподарства', 'Транспорт',
       'Сфера послуг', 'Сільське господарство'], axis=1)

# %%
df.groupby(['year', 'source'], as_index=False).apply(reshape_df
 ).reset_index(drop=True
 ).fillna(0
#  ).to_csv('data_by_source.csv', index=False)

# %%
pd.read_csv('data_by_source.csv')
# Out:
#     year                  source   Всього  Промисловість  Домогосподарства  \
# 0   2012    Біопаливо та відходи   1029.0           46.0             936.0
# 1   2012                 Вугілля   9212.0         8310.0             715.0
# 2   2012                     Газ  21698.0         5272.0           13760.0
# 3   2012          Електроенергія  11130.0         5102.0            3105.0
# 4   2012    Електроенергія з ВДЕ    710.0            0.0             198.0
# 5   2012  Нафта та нафтопродукти  11347.0         1246.0              71.0
# 6   2012         Сонячна енергія      0.0            0.0               0.0
# 7   2012         Теплова енергія  11853.0         4538.0            4677.0
# 8   2012   Теплова енергія з ВДЕ     12.3            5.0               5.0
# 9   2035    Біопаливо та відходи   5695.0          478.0             137.0
# 10  2035                 Вугілля   5419.0         4910.0             395.0
# 11  2035                     Газ   7615.0         1552.0            5450.0
# 12  2035          Електроенергія   6457.0         3374.0            1325.0
# 13  2035    Електроенергія з ВДЕ  10964.0            0.0            2251.0
# 14  2035  Нафта та нафтопродукти   5873.0          676.0               0.0
# 15  2035         Сонячна енергія    657.0            0.0             642.0
# 16  2035         Теплова енергія   6435.0         2090.0            2867.0
# 17  2035   Теплова енергія з ВДЕ   3904.0         1268.0            1739.0
# 18  2050    Біопаливо та відходи   7334.0         1235.0               0.0
# 19  2050                 Вугілля    621.0          547.0               0.0
# 20  2050                     Газ    460.1          276.0               0.0
# 21  2050          Електроенергія   1920.0          983.0             403.0
# 22  2050    Електроенергія з ВДЕ  25292.0            0.0            5309.0
# 23  2050  Нафта та нафтопродукти      3.0            0.0               0.0
# 24  2050         Сонячна енергія   4316.0            0.0            3304.0
# 25  2050         Теплова енергія   1604.0          503.0             834.0
# 26  2050   Теплова енергія з ВДЕ   7446.0         2335.0            3873.0
#
#     Транспорт  Сфера послуг  Сільське господарство
# 0         0.0          27.0                   20.0
# 1        12.0         161.0                   14.0
# 2      2050.0         463.0                  153.0
# 3       750.0        1861.0                  312.0
# 4        48.0         119.0                   20.0
# 5      8588.0          78.0                 1364.0
# 6         0.0           0.0                    0.0
# 7         0.0        2326.0                  312.0
# 8         0.0           2.0                    0.3
# 9      3521.0         440.0                 1119.0
# 10       12.0         100.0                    2.0
# 11      214.0         295.0                  104.0
# 12      647.0         967.0                  144.0
# 13     1098.0        1642.0                  245.0
# 14     4426.0           0.0                  771.0
# 15        0.0          14.0                    0.0
# 16        0.0        1231.0                  247.0
# 17        0.0         747.0                  150.0
# 18     3787.0          80.0                 2232.0
# 19        0.0          74.0                    0.0
# 20        0.1         184.0                    0.0
# 21      254.0         247.0                   33.0
# 22     3346.0        3252.0                  439.0
# 23        3.0           0.0                    0.0
# 24     3346.0        1012.0                    0.0
# 25        0.0         183.0                   84.0
# 26        0.0         850.0                  388.0

# %%
order = df[['source', 'is_vde']].drop_duplicates(
                               ).reset_index(
                               ).sort_values('index', ascending=False
                               ).reset_index(drop=True)

# %%
order = dict(map(lambda v: (v[1], {'index': v[0], 'is_vde': bool(v[2])}), order.values))

# %%
with open('sources_order.json', 'w') as f:
    json.dump(order, f, allow_nan=False, ensure_ascii=False)

# %%
measures = {k.capitalize(): v for k, v in measures.items()}

# %%
with open('measures.json', 'w') as f:
    json.dump(measures, f, allow_nan=False, ensure_ascii=False)

# %% [markdown]
# ## new data

# %%
df = pd.read_csv('data_from_report.csv', sep='\t')
df.columns = ['source', 'sphere', 'scenario', 'Y2012', 'Y2015', 'Y2020', 'Y2025', 'Y2030',
       'Y2035', 'Y2040', 'Y2045', 'Y2050']
df = pd.wide_to_long(df, stubnames='Y', i=['source', 'sphere', 'scenario'], j='year').reset_index()
df.columns = ['source', 'sphere', 'scenario', 'year', 'ktne']

df = df.loc[df.source != 'Всього'].copy()

# %%
totals = df.loc[df.sphere == 'загалом'].copy()
df = df.loc[df.sphere != 'загалом'].copy()

new_total = df.groupby(['source', 'scenario', 'year'], as_index=False).ktne.sum()
new_total['sphere'] = 'загалом'
df = pd.concat([df, new_total], ignore_index=True, sort=False)
# df.to_csv('data_report_longest.csv', index=False)

# %%
df = pd.read_csv('data_report_longest.csv')

# %%
def reshape_df(d):
    new = d.pivot('year', 'sphere', 'ktne').reset_index()
    new['source'] = d.source.iloc[0]
    new['scenario'] = d.scenario.iloc[0]
    return new

df.groupby(['year', 'source', 'scenario'], as_index=False
          ).apply(reshape_df
          ).reset_index(drop=True
          ).fillna(0
          ).to_csv('data_report_wide.csv', index=False)
# Out:
# /home/nr/ongoing/ecoaction/env/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:1142: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   result = concat(values, axis=self.axis, keys=keys)
#          scenario                  source  year  загалом  населення  \
# 0         Базовий    Біопаливо та відходи  2012   1029.0      936.0
# 1     Ліберальний    Біопаливо та відходи  2012   1029.0      936.0
# 2    Революційний    Біопаливо та відходи  2012   1029.0      936.0
# 3         Базовий                 Вугілля  2012   9212.0      715.0
# 4     Ліберальний                 Вугілля  2012   9212.0      715.0
# 5    Революційний                 Вугілля  2012   9212.0      715.0
# 6         Базовий                     Газ  2012  21698.0    13760.0
# 7     Ліберальний                     Газ  2012  21698.0    13760.0
# 8    Революційний                     Газ  2012  21698.0    13760.0
# 9         Базовий          Електроенергія  2012  11131.0     3105.0
# 10    Ліберальний          Електроенергія  2012  11130.0     3105.0
# 11   Революційний          Електроенергія  2012  11130.0     3105.0
# 12        Базовий    Електроенергія з ВДЕ  2012    709.0      198.0
# 13    Ліберальний    Електроенергія з ВДЕ  2012    710.0      198.0
# 14   Революційний    Електроенергія з ВДЕ  2012    710.0      198.0
# 15        Базовий  Нафта та нафтопродукти  2012  11347.0       71.0
# 16    Ліберальний  Нафта та нафтопродукти  2012  11347.0       71.0
# 17   Революційний  Нафта та нафтопродукти  2012  11347.0       71.0
# 18    Ліберальний         Сонячна енергія  2012      0.0        0.0
# 19   Революційний         Сонячна енергія  2012      0.0        0.0
# 20        Базовий         Теплова енергія  2012  11853.0     4677.0
# 21    Ліберальний         Теплова енергія  2012  11853.0     4677.0
# 22   Революційний         Теплова енергія  2012  11853.0     4677.0
# 23        Базовий   Теплова енергія з ВДЕ  2012     12.0        5.0
# 24    Ліберальний   Теплова енергія з ВДЕ  2012     12.0        5.0
# 25   Революційний   Теплова енергія з ВДЕ  2012     12.3        5.0
# 26        Базовий    Біопаливо та відходи  2015   1282.0     1097.0
# 27    Ліберальний    Біопаливо та відходи  2015   1282.0     1097.0
# 28   Революційний    Біопаливо та відходи  2015   1282.0     1097.0
# 29        Базовий                 Вугілля  2015   5952.0      303.0
# ..            ...                     ...   ...      ...        ...
# 204  Революційний         Теплова енергія  2045   3466.0     1689.0
# 205       Базовий   Теплова енергія з ВДЕ  2045    209.0       81.0
# 206   Ліберальний   Теплова енергія з ВДЕ  2045   1675.0      387.0
# 207  Революційний   Теплова енергія з ВДЕ  2045   6118.0     2980.0
# 208       Базовий    Біопаливо та відходи  2050   3039.0        0.0
# 209   Ліберальний    Біопаливо та відходи  2050   3630.0        0.0
# 210  Революційний    Біопаливо та відходи  2050   7334.0        0.0
# 211       Базовий                 Вугілля  2050  12033.0      144.0
# 212   Ліберальний                 Вугілля  2050  10661.0       16.0
# 213  Революційний                 Вугілля  2050    621.0        0.0
# 214       Базовий                     Газ  2050  20578.0    14357.0
# 215   Ліберальний                     Газ  2050   9567.0     4934.0
# 216  Революційний                     Газ  2050    460.1        0.0
# 217       Базовий          Електроенергія  2050  18991.0     3959.0
# 218   Ліберальний          Електроенергія  2050   9666.0     2108.0
# 219  Революційний          Електроенергія  2050   1920.0      403.0
# 220       Базовий    Електроенергія з ВДЕ  2050   1321.0      276.0
# 221   Ліберальний    Електроенергія з ВДЕ  2050   7817.0     1705.0
# 222  Революційний    Електроенергія з ВДЕ  2050  25292.0     5309.0
# 223       Базовий  Нафта та нафтопродукти  2050  15891.0      148.0
# 224   Ліберальний  Нафта та нафтопродукти  2050   7750.0        0.0
# 225  Революційний  Нафта та нафтопродукти  2050      3.0        0.0
# 226   Ліберальний         Сонячна енергія  2050   5396.0     3713.0
# 227  Революційний         Сонячна енергія  2050   1012.0        0.0
# 228       Базовий         Теплова енергія  2050  13050.0     5091.0
# 229   Ліберальний         Теплова енергія  2050   4338.0      960.0
# 230  Революційний         Теплова енергія  2050   1604.0      834.0
# 231       Базовий   Теплова енергія з ВДЕ  2050    232.0       90.0
# 232   Ліберальний   Теплова енергія з ВДЕ  2050   1835.0      406.0
# 233  Революційний   Теплова енергія з ВДЕ  2050   7446.0     3873.0
#
#      промисловість  сфера послуг  сільське господарство  транспорт
# 0             46.0          27.0                   20.0        0.0
# 1             46.0          27.0                   20.0        0.0
# 2             46.0          27.0                   20.0        0.0
# 3           8310.0         161.0                   14.0       12.0
# 4           8310.0         161.0                   14.0       12.0
# 5           8310.0         161.0                   14.0       12.0
# 6           5272.0         463.0                  153.0     2050.0
# 7           5272.0         463.0                  153.0     2050.0
# 8           5272.0         463.0                  153.0     2050.0
# 9           5102.0        1862.0                  312.0      750.0
# 10          5102.0        1861.0                  312.0      750.0
# 11          5102.0        1861.0                  312.0      750.0
# 12           325.0         118.0                   20.0       48.0
# 13           325.0         119.0                   20.0       48.0
# 14           325.0         119.0                   20.0       48.0
# 15          1246.0          78.0                 1364.0     8588.0
# 16          1246.0          78.0                 1364.0     8588.0
# 17          1246.0          78.0                 1364.0     8588.0
# 18             0.0           0.0                    0.0        0.0
# 19             0.0           0.0                    0.0        0.0
# 20          4538.0        2326.0                  312.0        0.0
# 21          4538.0        2326.0                  312.0        0.0
# 22          4538.0        2326.0                  312.0        0.0
# 23             5.0           2.0                    0.0        0.0
# 24             5.0           2.0                    0.0        0.0
# 25             5.0           2.0                    0.3        0.0
# 26            86.0          46.0                   19.0       34.0
# 27            86.0          46.0                   19.0       34.0
# 28            86.0          46.0                   19.0       34.0
# 29          5569.0          67.0                    9.0        4.0
# ..             ...           ...                    ...        ...
# 204         1106.0         508.0                  163.0        0.0
# 205           68.0          53.0                    7.0        0.0
# 206          771.0         422.0                   95.0        0.0
# 207         1953.0         897.0                  288.0        0.0
# 208          219.0         901.0                   31.0     1888.0
# 209          211.0          79.0                 2127.0     1213.0
# 210         1235.0          80.0                 2232.0     3787.0
# 211        11761.0          96.0                   20.0       12.0
# 212        10558.0          74.0                    1.0       12.0
# 213          547.0          74.0                    0.0        0.0
# 214         3743.0         941.0                  176.0     1361.0
# 215         2467.0         716.0                   36.0     1414.0
# 216          276.0         184.0                    0.0        0.1
# 217        10739.0        2801.0                  472.0     1020.0
# 218         4514.0        1226.0                  243.0     1575.0
# 219          983.0         247.0                   33.0      254.0
# 220          748.0         195.0                   31.0       71.0
# 221         3651.0         991.0                  196.0     1274.0
# 222        12946.0        3252.0                  439.0     3346.0
# 223         1216.0          49.0                 2121.0    12357.0
# 224         1322.0          23.0                   62.0     6343.0
# 225            0.0           0.0                    0.0        3.0
# 226            0.0        1683.0                    0.0        0.0
# 227            0.0        1012.0                    0.0        0.0
# 228         4254.0        3242.0                  463.0        0.0
# 229         2139.0         915.0                  324.0        0.0
# 230          503.0         183.0                   84.0        0.0
# 231           76.0          58.0                    8.0        0.0
# 232          905.0         387.0                  137.0        0.0
# 233         2335.0         850.0                  388.0        0.0
#
# [234 rows x 9 columns]

# %% [markdown]
# ### parse costs

# %%
import re

# %%
with open('costs_to_parse.txt') as f:
    costs = f.read()

costs = re.sub('\s{2,}|\s+(?<=\d)|\s+(?=\d)', '\n', costs)

scens = re.split('\s*-{3,}\s*', costs)

snames = ['Консервативний', 'Ліберальний', 'Революційний']

sdfs = [];

for i, s in enumerate(scens):
    sdf = pd.DataFrame(list(map(lambda r: r.strip().split('\n'), re.findall('[^0-9]+[^А-яЄєЇїІіҐґ]+', s))))
    sdf['scenario'] = snames[i]
    sdfs.append(sdf)
    
sdf = pd.concat(sdfs, ignore_index=True, sort=False
       ).replace({'-': 0})

sdf.columns = ['action', 'Y2012', 'Y2015', 'Y2020', 'Y2025', 'Y2030', 'Y2035', 'Y2040', 'Y2045', 'Y2050', 'scenario']

sdf = pd.wide_to_long(sdf, stubnames='Y', i=['action', 'scenario',], j='year').reset_index()

sdf.columns = ['action', 'scenario', 'year', 'm_euro']
# sdf.to_csv('costs.csv', index=False)
